# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
df = pd.read_csv('september_2024.csv')

# %%
df.head(20)
# Out:
#     Order #            Sent Date                   Modifier  \
# 0         1  2024-09-01 11:08:00                    Regular
# 1         1  2024-09-01 11:08:00                    Cheddar
# 2         1  2024-09-01 11:08:00                    Brisket
# 3         1  2024-09-01 11:08:00                   Broccoli
# 4         1  2024-09-01 11:08:00                Breadcrumbs
# 5         1  2024-09-01 11:08:00            Garlic Parmesan
# 6         1  2024-09-01 11:08:00        Cheesy Garlic Bread
# 7         1  2024-09-01 11:08:00  Unlimited Fountain Drinks
# 8         4  2024-09-01 11:08:00                    Regular
# 9         4  2024-09-01 11:08:00                    Cheddar
# 10        4  2024-09-01 11:08:00                      Bacon
# 11        4  2024-09-01 11:08:00                       Corn
# 12        4  2024-09-01 11:08:00                 No Drizzle
# 13        4  2024-09-01 11:08:00        Cheesy Garlic Bread
# 14        4  2024-09-01 11:08:00  Unlimited Fountain Drinks
# ...

# %%
df.shape
# Out:
# (47512, 6)

# %%
df.count()
# Out:
# Order #                  47512
# Sent Date                47511
# Modifier                 47511
# Option Group Name        47476
# Parent Menu Selection    47511
# Order ID                 47512
# dtype: int64

# %%
df['Order ID'].unique()
# Out:
# array(['1-1', '1-4', '1-3', ..., '30-200', '30-5002', '30-3001'],
#       dtype=object)

# %%
df.head(1000)
# Out:
#      Order #            Sent Date                   Modifier  \
# 0          1  2024-09-01 11:08:00                    Regular
# 1          1  2024-09-01 11:08:00                    Cheddar
# 2          1  2024-09-01 11:08:00                    Brisket
# 3          1  2024-09-01 11:08:00                   Broccoli
# 4          1  2024-09-01 11:08:00                Breadcrumbs
# ..       ...                  ...                        ...
# 995       85  2024-09-01 15:28:00            Garlic Parmesan
# 996       85  2024-09-01 15:28:00        Cheesy Garlic Bread
# 997       85  2024-09-01 15:28:00  Unlimited Fountain Drinks
# 998       86  2024-09-01 15:28:00                    Regular
# 999       86  2024-09-01 15:28:00                    Cheddar
#
#         Option Group Name Parent Menu Selection Order ID
# 0                   Noods        Mac and Cheese      1-1
# 1      Choose Your Cheese        Mac and Cheese      1-1
# 2       Choose Your Meats        Mac and Cheese      1-1
# ...

# %%
result = df.groupby('Order ID').agg(
    date=('Sent Date', 'first'),
    modifier_count=('Modifier', 'count')
).sort_values(by='date').reset_index()

# %%
result.head(20)
# Out:
#    Order ID                 date  modifier_count
# 0       1-1  2024-09-01 11:08:00               8
# 1       1-4  2024-09-01 11:08:00               7
# 2       1-3  2024-09-01 11:09:00               7
# 3       1-6  2024-09-01 11:10:00               7
# 4       1-7  2024-09-01 11:17:00              19
# 5       1-9  2024-09-01 11:41:00              15
# 6      1-11  2024-09-01 11:52:00              24
# 7      1-13  2024-09-01 11:58:00              11
# 8      1-14  2024-09-01 11:59:00              13
# 9      1-15  2024-09-01 12:01:00              16
# 10     1-16  2024-09-01 12:03:00              11
# 11     1-17  2024-09-01 12:11:00              23
# 12     1-21  2024-09-01 12:13:00               7
# 13     1-20  2024-09-01 12:14:00               7
# 14     1-18  2024-09-01 12:14:00               7
# 15     1-19  2024-09-01 12:15:00               8
# 16     1-22  2024-09-01 12:19:00              16
# 17     1-24  2024-09-01 12:19:00              17
# ...

# %%
result['date'] = pd.to_datetime(result['date'])
result['time_interval'] = result['date'].dt.floor('15T').dt.time

# %%
result = result.groupby('time_interval').agg(
    count=('Order ID', 'count'),
    total=('modifier_count', 'mean')
).reset_index()

# %%
result.head(1000)
# Out:
#    time_interval  count      total
# 0       07:30:00      1   8.000000
# 1       09:15:00      1   4.000000
# 2       09:45:00      2   8.000000
# 3       10:15:00      1  12.000000
# 4       10:30:00      3  10.000000
# 5       10:45:00     11   9.727273
# 6       11:00:00     69  11.173913
# 7       11:15:00    106  12.264151
# 8       11:30:00     82  10.841463
# 9       11:45:00     83  11.807229
# 10      12:00:00    103  11.456311
# 11      12:15:00    116  10.663793
# 12      12:30:00    182  10.906593
# 13      12:45:00    118  11.076271
# 14      13:00:00     92  11.913043
# 15      13:15:00     81  11.135802
# 16      13:30:00    117  12.256410
# 17      13:45:00    119  12.042017
# 18      14:00:00    124  11.072581
# 19      14:15:00     85  11.247059
# 20      14:30:00     72   9.791667
# 21      14:45:00    109  10.944954
# 22      15:00:00     96  10.822917
# 23      15:15:00     72  11.583333
# 24      15:30:00     70  11.614286
# 25      15:45:00     79  11.253165
# ...

# %%
result['time_interval'] = pd.to_datetime(result['time_interval'], format='%H:%M')
result.dtypes
# Out:
# time_interval    datetime64[ns]
# count                     int64
# total                   float64
# dtype: object

# %%
result.head(1000)
# Out:
#          time_interval  count      total
# 0  1900-01-01 07:30:00      1   8.000000
# 1  1900-01-01 09:15:00      1   4.000000
# 2  1900-01-01 09:45:00      2   8.000000
# 3  1900-01-01 10:15:00      1  12.000000
# 4  1900-01-01 10:30:00      3  10.000000
# 5  1900-01-01 10:45:00     11   9.727273
# 6  1900-01-01 11:00:00     69  11.173913
# 7  1900-01-01 11:15:00    106  12.264151
# 8  1900-01-01 11:30:00     82  10.841463
# 9  1900-01-01 11:45:00     83  11.807229
# 10 1900-01-01 12:00:00    103  11.456311
# 11 1900-01-01 12:15:00    116  10.663793
# 12 1900-01-01 12:30:00    182  10.906593
# 13 1900-01-01 12:45:00    118  11.076271
# 14 1900-01-01 13:00:00     92  11.913043
# 15 1900-01-01 13:15:00     81  11.135802
# 16 1900-01-01 13:30:00    117  12.256410
# 17 1900-01-01 13:45:00    119  12.042017
# 18 1900-01-01 14:00:00    124  11.072581
# 19 1900-01-01 14:15:00     85  11.247059
# 20 1900-01-01 14:30:00     72   9.791667
# 21 1900-01-01 14:45:00    109  10.944954
# ...

# %%
# Set Seaborn style
sns.set(style="whitegrid")

fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot 'count' on the first y-axis
sns.lineplot(data=result, x='time_interval', y='count', ax=ax1, color='tab:blue', marker='o', label='Order Count')
ax1.set_xlabel('Time Interval (hh:mm)')
ax1.set_ylabel('Order Count', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Plot 'total' on the second y-axis
ax2 = ax1.twinx()
sns.lineplot(data=df, x='time_interval', y='total', ax=ax2, color='tab:red', marker='x', label='Avg Components per Order')
ax2.set_ylabel('Avg Components per Order', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

time_fmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(time_fmt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 14
#      12 # Plot 'total' on the second y-axis
#      13 ax2 = ax1.twinx()
# ---> 14 sns.lineplot(data=df, x='time_interval', y='total', ax=ax2, color='tab:red', marker='x', label='Avg Components per Order')
#      15 ax2.set_ylabel('Avg Components per Order', color='tab:red')
#      16 ax2.tick_params(axis='y', labelcolor='tab:red')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
# ...
