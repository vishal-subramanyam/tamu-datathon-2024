# %%
import pandas as pd
myfile = pd.read_csv('april_2024.csv')

# %%
myfile.head()
# Out:
#    Order #            Sent Date     Modifier     Option Group Name  \
# 0       18  2024-04-13 11:34:00      Regular                 Noods
# 1       18  2024-04-13 11:34:00      Cheddar    Choose Your Cheese
# 2       18  2024-04-13 11:34:00  Pulled Pork     Choose Your Meats
# 3       18  2024-04-13 11:34:00     Broccoli  Choose Your Toppings
# 4       18  2024-04-13 11:34:00     Tomatoes  Choose Your Toppings
#
#   Parent Menu Selection Order ID
# 0        Mac and Cheese    13-18
# 1        Mac and Cheese    13-18
# 2        Mac and Cheese    13-18
# 3        Mac and Cheese    13-18
# 4        Mac and Cheese    13-18

# %%
for i in myfile["Option Group Name"]:
    print(i)
# Out:
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# Choose Your Meats
# Choose Your Toppings
# Choose Your Drizzles
# Choose Your Side
# Choose Your Drink
# Noods
# Choose Your Cheese
# ...
